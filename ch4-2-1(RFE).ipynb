# %%
# ch4-2.py
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(module='sklearn*', action='ignore', category=DeprecationWarning)

# %%
# 데이터로드 (ch4-2(붓꽃데이터).csv : 데이터 원본 파일)
# encoding : 윈도우즈 환경에서의 한글 처리
# engine : python 3.6에서 한글이 포함된 파일이름 사용
rawData_org = pd.read_csv('datasets/국민건강정보/NHIS_OPEN_GJ_2017.csv', encoding='CP949', engine='python')

# %%
# 원본데이터의 튜플 수와 컬럼수 출력
rawData_org.shape
# Out:
# (1000000, 34)

# %%
# 의사결정트리에 사용할 속성리스트
feature_columns_to_use = ['성별코드', '연령대코드(5세단위)', '신장(5Cm단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)',
                    '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)', '트리글리세라이드', 'HDL콜레스테롤',
                    'LDL콜레스테롤', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '음주여부']

rawData = rawData_org[feature_columns_to_use]

# %%
# 속성값이 NULL인 튜플 제외
rawData = rawData.dropna()

# 인덱스 재설정
rawData.reset_index(inplace=True, drop=True)

# 원본데이터의 튜플 수와 컬럼수 출력
rawData.shape
# Out:
# (990910, 22)

# %%
import random as rd  # 샘플링을 위한 random 패키지 임포트

# 1) 샘플링을 통한 수량 축소
# 원본데이터 중 50,000개를 튜플만 샘플링
# len() : 데이터프레임의 크기를 구하는 함수
sample_idx = rd.sample(range(0, len(rawData)), 50000)

# 인덱스 값 정렬(오름차순)
sample_idx.sort()

sample_idx
# Out:
# [5,
#  8,
#  20,
#  34,
#  46,
#  55,
#  148,
#  176,
#  196,
#  219,
#  229,
#  246,
#  263,
#  281,
#  306,
#  311,
#  321,
#  352,
#  355,
#  365,
#  381,
#  402,
#  436,
#  469,
#  500,
#  528,
#  551,
#  612,
#  618,
#  620,
#  624,
#  633,
#  641,
#  656,
#  682,
#  687,
#  688,
#  708,
#  723,
#  728,
#  782,
#  793,
#  806,
#  855,
#  869,
#  875,
#  889,
#  895,
#  898,
#  902,
#  942,
#  958,
#  965,
#  984,
#  1028,
#  1052,
#  1053,
#  1087,
#  1095,
#  1097,
#  1125,
#  1159,
#  1195,
#  1197,
#  1266,
#  1288,
#  1297,
#  1312,
#  1318,
#  1352,
#  1363,
#  1385,
#  1404,
#  1409,
#  1438,
#  1503,
#  1506,
#  1552,
#  1609,
#  1626,
#  1656,
#  1702,
#  1728,
#  1825,
#  1846,
#  1880,
#  1905,
#  1921,
#  1939,
#  1940,
#  1950,
#  1956,
#  1977,
#  1984,
#  2005,
#  2031,
#  2046,
#  2047,
#  2059,
#  2175,
#  2199,
#  2218,
#  2251,
#  2290,
#  2302,
#  2353,
#  2368,
#  2380,
#  2413,
#  2415,
#  2451,
#  2472,
#  2479,
#  2483,
#  2491,
#  2504,
#  2511,
#  2524,
#  2545,
#  2594,
#  2621,
#  2629,
#  2637,
#  2638,
#  2647,
#  2648,
#  2660,
#  2666,
#  2738,
#  2746,
#  2748,
#  2797,
#  2802,
#  2816,
#  2829,
#  2852,
#  2853,
#  2880,
#  2934,
#  2975,
#  2976,
#  2986,
#  2990,
#  3009,
#  3046,
#  3047,
#  3056,
#  3078,
#  3089,
#  3130,
#  3144,
#  3177,
#  3182,
#  3191,
#  3203,
#  3235,
#  3263,
#  3271,
#  3284,
#  3313,
#  3328,
#  3351,
#  3353,
#  3357,
#  3373,
#  3380,
#  3386,
#  3414,
#  3491,
#  3510,
#  3522,
#  3575,
#  3618,
#  3619,
#  3632,
#  3637,
#  3656,
#  3665,
#  3684,
#  3685,
#  3695,
#  3703,
#  3711,
#  3721,
#  3724,
#  3738,
#  3741,
#  3751,
#  3758,
#  3793,
#  3829,
#  3873,
#  3874,
#  3912,
#  3944,
#  3987,
#  4003,
#  4019,
#  4025,
#  4047,
#  4051,
#  4052,
#  4064,
#  4105,
#  4112,
#  4132,
#  4199,
#  4207,
#  4234,
#  4271,
#  4318,
#  4325,
#  4340,
#  4345,
#  4346,
#  4410,
#  4412,
#  4438,
#  4440,
#  4449,
#  4486,
#  4499,
#  4500,
#  4529,
#  4533,
#  4597,
#  4598,
#  4602,
#  4608,
#  4627,
#  4633,
#  4671,
#  4672,
#  4715,
#  4734,
#  4747,
#  4761,
#  4771,
#  4848,
#  4924,
#  4940,
#  4953,
#  4972,
#  5008,
#  5040,
#  5043,
#  5059,
#  5078,
#  5093,
#  5104,
#  5111,
#  5121,
#  5133,
#  5134,
#  5145,
#  5185,
#  5196,
#  5202,
#  5206,
#  5222,
#  5223,
#  5242,
#  5263,
#  5276,
#  5279,
#  5302,
#  5316,
#  5317,
#  5338,
#  5341,
#  5349,
#  5350,
#  5364,
#  5368,
#  5380,
#  5387,
#  5438,
#  5442,
#  5445,
#  5476,
#  5480,
#  5485,
#  5487,
#  5488,
#  5500,
#  5504,
#  5535,
#  5541,
#  5590,
#  5625,
#  5640,
#  5642,
#  5650,
#  5652,
#  5673,
#  5679,
#  5686,
#  5689,
#  5700,
#  5709,
#  5710,
#  5713,
#  5715,
#  5756,
#  5785,
#  5821,
#  5859,
#  5862,
#  5872,
#  5945,
#  5952,
#  5958,
#  5964,
#  5967,
#  5977,
#  5989,
#  5999,
#  6026,
#  6087,
#  6093,
#  6104,
#  6130,
#  6182,
#  6189,
#  6218,
#  6251,
#  6280,
#  6284,
#  6298,
#  6309,
#  6333,
#  6340,
#  6342,
#  6367,
#  6461,
#  6464,
#  6466,
#  6477,
#  6500,
#  6503,
#  6506,
#  6537,
#  6554,
#  6555,
#  6596,
#  6601,
#  6640,
#  6647,
#  6652,
#  6674,
#  6709,
#  6710,
#  6711,
#  6720,
#  6743,
#  6765,
#  6789,
#  6841,
#  6881,
#  6905,
#  6915,
#  6943,
#  6960,
#  7029,
#  7041,
#  7054,
#  7066,
#  7157,
#  7162,
#  7186,
#  7226,
#  7244,
#  7260,
#  7286,
#  7299,
#  7303,
#  7304,
#  7310,
#  7333,
#  7347,
#  7367,
#  7370,
#  7442,
#  7462,
#  7524,
#  7531,
#  7540,
#  7558,
#  7577,
#  7591,
#  7607,
#  7615,
#  7620,
#  7640,
#  7649,
#  7657,
#  7665,
#  7692,
#  7705,
#  7706,
#  7729,
#  7744,
#  7751,
#  7769,
#  7821,
#  7824,
#  7836,
#  7840,
#  7853,
#  7860,
#  7869,
#  7938,
#  7948,
#  7954,
#  7962,
#  7992,
#  8027,
#  8030,
#  8062,
#  8077,
#  8103,
#  8117,
#  8169,
#  8180,
#  8190,
#  8191,
#  8221,
#  8235,
#  8248,
#  8259,
#  8273,
#  8350,
#  8354,
#  8390,
#  8411,
#  8431,
#  8453,
#  8467,
#  8480,
#  8514,
#  8573,
#  8581,
#  8588,
#  8612,
#  8623,
#  8645,
#  8652,
#  8683,
#  8693,
#  8720,
#  8725,
#  8743,
#  8825,
#  8845,
#  8905,
#  8970,
#  9042,
#  9048,
#  9052,
#  9059,
#  9080,
#  9097,
#  9107,
#  9121,
#  9194,
#  9241,
#  9275,
#  9282,
#  9286,
#  9325,
#  9358,
#  9395,
#  9400,
#  9403,
#  9412,
#  9437,
#  9468,
#  9474,
#  9535,
#  9540,
#  9545,
#  9591,
#  9610,
#  9628,
#  9641,
#  9646,
#  9660,
#  9667,
#  9675,
#  9676,
#  9679,
#  9709,
#  9774,
#  9798,
#  9837,
#  9838,
#  9841,
#  9850,
#  9869,
#  9889,
#  9953,
#  9964,
#  10010,
#  10052,
#  10063,
#  10074,
#  10075,
#  10095,
#  10099,
#  10151,
#  10157,
#  10159,
#  10167,
#  10174,
#  10210,
#  10244,
#  10246,
#  10266,
#  10283,
#  10295,
#  10327,
#  10360,
#  10369,
#  10418,
#  10433,
#  10436,
#  10437,
#  10440,
#  10485,
#  10491,
#  10511,
#  10540,
#  10578,
#  10588,
#  10614,
#  10615,
#  10640,
#  10665,
#  10682,
#  10704,
#  10774,
#  10781,
#  10797,
#  10806,
#  10808,
#  10812,
#  10829,
#  10841,
#  10851,
#  10881,
#  10890,
#  10894,
#  10898,
#  10900,
#  10926,
#  10929,
#  10935,
#  10960,
#  10967,
#  10977,
#  11003,
#  11036,
#  11059,
#  11074,
#  11080,
#  11090,
#  11103,
#  11112,
#  11121,
#  11138,
#  11151,
#  11159,
#  11183,
#  11203,
#  11207,
#  11210,
#  11218,
#  11223,
#  11257,
#  11267,
#  11304,
#  11320,
#  11335,
#  11387,
#  11393,
#  11400,
#  11420,
#  11430,
#  11462,
#  11491,
#  11507,
#  11509,
#  11518,
#  11548,
#  11553,
#  11571,
#  11616,
#  11617,
#  11620,
#  11621,
#  11635,
#  11637,
#  11640,
#  11674,
#  11676,
#  11683,
#  11693,
#  11699,
#  11702,
#  11724,
#  11754,
#  11756,
#  11757,
#  11762,
#  11774,
#  11783,
#  11787,
#  11820,
#  11840,
#  11859,
#  11884,
#  11896,
#  11902,
#  11904,
#  11969,
#  11976,
#  11993,
#  11999,
#  12011,
#  12031,
#  12044,
#  12047,
#  12055,
#  12076,
#  12086,
#  12119,
#  12120,
#  12140,
#  12157,
#  12166,
#  12197,
#  12315,
#  12346,
#  12351,
#  12359,
#  12391,
#  12447,
#  12475,
#  12482,
#  12493,
#  12504,
#  12509,
#  12532,
#  12533,
#  12550,
#  12650,
#  12657,
#  12659,
#  12667,
#  12670,
#  12692,
#  12709,
#  12727,
#  12819,
#  12823,
#  12843,
#  12853,
#  12857,
#  12860,
#  12945,
#  12995,
#  13005,
#  13028,
#  13040,
#  13047,
#  13072,
#  13087,
#  13097,
#  13147,
#  13157,
#  13194,
#  13196,
#  13225,
#  13227,
#  13235,
#  13241,
#  13243,
#  13251,
#  13306,
#  13314,
#  13319,
#  13339,
#  13353,
#  13390,
#  13410,
#  13446,
#  13451,
#  13494,
#  13495,
#  13527,
#  13560,
#  13569,
#  13574,
#  13583,
#  13614,
#  13633,
#  13646,
#  13654,
#  13683,
#  13697,
#  13701,
#  13710,
#  13759,
#  13766,
#  13800,
#  13811,
#  13848,
#  13850,
#  13866,
#  13905,
#  13916,
#  13918,
#  13941,
#  13944,
#  13945,
#  13953,
#  13959,
#  13965,
#  14011,
#  14044,
#  14061,
#  14073,
#  14078,
#  14119,
#  14135,
#  14157,
#  14164,
#  14187,
#  14196,
#  14231,
#  14242,
#  14251,
#  14258,
#  14282,
#  14295,
#  14316,
#  14330,
#  14348,
#  14364,
#  14401,
#  14418,
#  14441,
#  14450,
#  14470,
#  14479,
#  14495,
#  14525,
#  14547,
#  14572,
#  14601,
#  14635,
#  14665,
#  14685,
#  14698,
#  14699,
#  14709,
#  14747,
#  14756,
#  14759,
#  14761,
#  14825,
#  14849,
#  14851,
#  14938,
#  14945,
#  14960,
#  15000,
#  15002,
#  15012,
#  15017,
#  15029,
#  15041,
#  15134,
#  15145,
#  15169,
#  15178,
#  15180,
#  15192,
#  15203,
#  15215,
#  15217,
#  15220,
#  15226,
#  15241,
#  15254,
#  15262,
#  15263,
#  15275,
#  15298,
#  15337,
#  15339,
#  15348,
#  15358,
#  15364,
#  15428,
#  15470,
#  15485,
#  15512,
#  15557,
#  15560,
#  15586,
#  15591,
#  15592,
#  15657,
#  15663,
#  15676,
#  15682,
#  15707,
#  15708,
#  15726,
#  15733,
#  15742,
#  15745,
#  15754,
#  15783,
#  15784,
#  15788,
#  15803,
#  15814,
#  15823,
#  15830,
#  15844,
#  15873,
#  15882,
#  15894,
#  15914,
#  15944,
#  15963,
#  15981,
#  16010,
#  16056,
#  16079,
#  16097,
#  16137,
#  16151,
#  16159,
#  16177,
#  16178,
#  16187,
#  16226,
#  16408,
#  16444,
#  16457,
#  16479,
#  16515,
#  16527,
#  16551,
#  16561,
#  16564,
#  16577,
#  16583,
#  16594,
#  16673,
#  16695,
#  16701,
#  16734,
#  16740,
#  16764,
#  16771,
#  16792,
#  16797,
#  16832,
#  16834,
#  16840,
#  16863,
#  16913,
#  16923,
#  16930,
#  16931,
#  16933,
#  16996,
#  17044,
#  17047,
#  17061,
#  17083,
#  17088,
#  17094,
#  17169,
#  17203,
#  17207,
#  17233,
#  17286,
#  17307,
#  17336,
#  17357,
#  17403,
#  17422,
#  17427,
#  17449,
#  17464,
#  17492,
#  17536,
#  17556,
#  17563,
#  17566,
#  17580,
#  17589,
#  17595,
#  17669,
#  17682,
#  17721,
#  17750,
#  17761,
#  17782,
#  17784,
#  17818,
#  17836,
#  17845,
#  17883,
#  17912,
#  17923,
#  17965,
#  17981,
#  17983,
#  17989,
#  18005,
#  18030,
#  18034,
#  18041,
#  18047,
#  18056,
#  18097,
#  18099,
#  18108,
#  18117,
#  18128,
#  18148,
#  18161,
#  18167,
#  18169,
#  18174,
#  18179,
#  18208,
#  18223,
#  18261,
#  18262,
#  18283,
#  18306,
#  18328,
#  18368,
#  18387,
#  18410,
#  18436,
#  18441,
#  18450,
#  18461,
#  18466,
#  18472,
#  18491,
#  18492,
#  18519,
#  18533,
#  18559,
#  18567,
#  18584,
#  18616,
#  18657,
#  18677,
#  18698,
#  18715,
#  18755,
#  18771,
#  18772,
#  18773,
#  18800,
#  18806,
#  18842,
#  18850,
#  18871,
#  18886,
#  18903,
#  18921,
#  18922,
#  18924,
#  18936,
#  18944,
#  18961,
#  18999,
#  19034,
#  19047,
#  19055,
#  19115,
#  19119,
#  19128,
#  19131,
#  19164,
#  19176,
#  19196,
#  19197,
#  19223,
#  ...]

# %%
# 샘플링 된 인덱스로 구성된 샘플 데이터프레임 생성
rawData_sample = rawData.loc[sample_idx]

rawData_sample.reset_index(inplace=True, drop=True) #  인덱스 재설정

# 첫 10개의 행만 출력
rawData_sample.head(10)
# Out:
#    성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0     1            8      170.0        70.0  84.8    1.2    1.0    1.0    1.0
# 1     1            8      170.0        80.0  93.0    0.7    0.9    1.0    1.0
# 2     2           11      155.0        55.0  80.0    0.5    0.5    1.0    1.0
# 3     2            5      155.0        40.0  70.0    1.5    1.5    1.0    1.0
# 4     2           10      155.0        50.0  70.0    1.2    1.2    1.0    1.0
# 5     1           16      155.0        55.0  83.0    0.5    0.8    1.0    1.0
# 6     1            6      175.0        85.0  90.0    1.5    1.5    1.0    1.0
# 7     1            8      180.0       100.0  96.0    1.0    1.0    1.0    1.0
# 8     1           11      175.0        95.0  96.0    1.5    1.2    1.0    1.0
# 9     2           10      150.0        50.0  72.0    1.5    1.5    1.0    1.0
#
#    수축기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0  115.0  ...     139.0      46.0     136.0  1.0      0.9        25.0
# 1  115.0  ...     185.0      32.0      89.0  1.0      1.0        31.0
# 2  117.0  ...     172.0      48.0     131.0  1.0      0.7        19.0
# 3  129.0  ...     110.0      56.0      92.0  1.0      0.5        19.0
# 4  115.0  ...      69.0      50.0     144.0  1.0      0.9        18.0
# 5  147.0  ...     103.0      43.0     116.0  1.0      0.9        24.0
# 6  117.0  ...      42.0      57.0      90.0  1.0      0.8        19.0
# 7  108.0  ...     268.0      71.0     118.0  1.0      1.1        29.0
# 8  109.0  ...     222.0      39.0     130.0  1.0      0.8        58.0
# 9  130.0  ...      86.0      68.0     108.0  1.0      0.7        16.0
#
#    (혈청지오티)ALT  감마지티피  흡연상태  음주여부
# 0        30.0   33.0   2.0   1.0
# 1        29.0   51.0   2.0   0.0
# 2        14.0   19.0   1.0   0.0
# 3        14.0   31.0   2.0   1.0
# 4        13.0   15.0   1.0   0.0
# 5        28.0   21.0   1.0   0.0
# 6        22.0   15.0   1.0   1.0
# 7        25.0   82.0   3.0   1.0
# 8        52.0   46.0   3.0   1.0
# 9        10.0    9.0   1.0   1.0
#
# [10 rows x 22 columns]

# %%
rawData_sample.shape
# Out:
# (50000, 22)

# %%
# nonnumeric 속성을 categrical 데이터로 변환
nonnumeric_columns = ['성별코드','음주여부']

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in nonnumeric_columns:
    rawData_sample[feature] = le.fit_transform(rawData_sample[feature])

# %%
# 소스 데이터프레임에서 분류(classification)을 위한 속성 집합
X = rawData_sample.loc[:, feature_columns_to_use[:-1]]  
y = rawData_sample.loc[:, '음주여부']  # 분류 클래스(class)

from sklearn.model_selection import train_test_split  # 분석모형 선택에 관련된 모듈
    
# 자동으로 데이터셋을 트레이닝셋과 테스트셋으로 분리해주는 함수로
# 트레이닝셋과 데이터셋의 비율을 7:3으로 세팅함
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
# Scikit-Learn 패키지 : 머신 러닝 교육 및 실무를 위한 패키지로 샘플 데이터셋,
# 다양한 기계학습 기법에 대한 함수 등을 포함하고 있음
from sklearn.ensemble import RandomForestClassifier  # 랜덤포리스트 기법에 관련된 모듈

# DecisionTreeClassifier() : 의사결정트리를 생성하는 함수
random_forest = RandomForestClassifier(n_estimators=20, random_state=0)
random_forest
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=20,
#                        n_jobs=None, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
# fit() : 트레이닝 데이터셋을 대상으로 의사결정트리 학습 진행
random_forest.fit(X_train, y_train)

# tree.predict() 함수를 활용하여 의사결정트리를 대상으로 테스트셋을 예측
y_pred_tr = random_forest.predict(X_test)

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(random_forest.score(X_train, y_train)))
print("Test Set Score1 : {:.2f}".format(random_forest.score(X_test, y_test)))
# Out:
# Train Set Score1 : 1.00
# Test Set Score1 : 0.71

# %%
from sklearn.metrics import accuracy_score  # 분류 정확도(classification accuracy)를 계산하는 모듈

# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.71

# %%
# RFE(Recursive Feature Elimination)
from sklearn.feature_selection import RFE

select = RFE(RandomForestClassifier(n_estimators=20, random_state=0), n_features_to_select = 10)
select.fit(X_train, y_train)
select
# Out:
# RFE(estimator=RandomForestClassifier(bootstrap=True, class_weight=None,
#                                      criterion='gini', max_depth=None,
#                                      max_features='auto', max_leaf_nodes=None,
#                                      min_impurity_decrease=0.0,
#                                      min_impurity_split=None,
#                                      min_samples_leaf=1, min_samples_split=2,
#                                      min_weight_fraction_leaf=0.0,
#                                      n_estimators=20, n_jobs=None,
#                                      oob_score=False, random_state=0, verbose=0,
#                                      warm_start=False),
#     n_features_to_select=10, step=1, verbose=0)

# %%
X_train_RFE = select.transform(X_train)
X_test_RFE = select.transform(X_test)
random_forest.fit(X_train_RFE, y_train)

# %%
# 속성(feature) 별 중요도를 저장하는 데이터프레임 생성 
sel_feature = pd.DataFrame({'중요도' : select.ranking_}, index = feature_columns_to_use[:-1])

# 중요도의 내림차순으로 정렬
sel_feature.sort_values(by='중요도', ascending=True)
# Out:
#              중요도
# 성별코드           1
# 연령대코드(5세단위)    1
# (혈청지오티)ALT     1
# 허리둘레           1
# LDL콜레스테롤       1
# HDL콜레스테롤       1
# 트리글리세라이드       1
# 수축기혈압          1
# 감마지티피          1
# 식전혈당(공복혈당)     1
# 신장(5Cm단위)      2
# (혈청지오티)AST     3
# 이완기혈압          4
# 흡연상태           5
# 체중(5Kg 단위)     6
# 시력(우)          7
# 혈청크레아티닌        8
# 시력(좌)          9
# 요단백           10
# 청력(우)         11
# 청력(좌)         12

# %%
# 점수 출력
print("Train Set Score1 : {:.2f}".format(random_forest.score(X_train_RFE, y_train)))
print("Test Set Score1 : {:.2f}".format(random_forest.score(X_test_RFE, y_test)))
# Out:
# Train Set Score1 : 1.00
# Test Set Score1 : 0.70

# %%
# accuracy_score() 함수를 활용하여 테스트셋의 실제 클래스와 예측된 클래스 간 정확도 측정
y_pred_tr = random_forest.predict(X_test_RFE)
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred_tr))
# Out:
# Accuracy: 0.70
