# %%
import pandas as pd
import numpy as np

rawData_org = pd.read_csv('datasets/국민건강정보/NHIS_OPEN_GJ_2017.csv', encoding='CP949', engine='python')

# %%
rawData_org
# Out:
#         기준년도  가입자일련번호  성별코드  연령대코드(5세단위)  시도코드  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  \
# 0       2017        1     1           13    46      170.0        65.0  91.0
# 1       2017        2     2            8    41      150.0        45.0  73.4
# 2       2017        3     1            8    45      175.0        75.0  94.0
# 3       2017        4     2           12    11      155.0        55.0  67.5
# 4       2017        5     1            8    41      175.0        75.0  93.0
# ...      ...      ...   ...          ...   ...        ...         ...   ...
# 999995  2017   999996     2            9    41      165.0        55.0  70.0
# 999996  2017   999997     2            9    11      165.0        50.0  68.0
# 999997  2017   999998     2           12    27      155.0        50.0  83.8
# 999998  2017   999999     1           11    47      160.0        70.0  99.0
# 999999  2017  1000000     2            9    27      165.0        60.0  74.0
#
#         시력(좌)  시력(우)  ...  감마지티피  흡연상태  음주여부  구강검진 수검여부  치아우식증유무  결손치유무  \
# 0         1.0    1.2  ...   25.0   3.0   0.0          1      NaN    NaN
# 1         1.2    1.0  ...   10.0   1.0   0.0          1      NaN    NaN
# 2         1.0    0.8  ...  136.0   1.0   0.0          1      NaN    NaN
# 3         0.9    1.0  ...   30.0   1.0   1.0          0      NaN    NaN
# 4         1.5    1.5  ...   68.0   3.0   0.0          0      NaN    NaN
# ...       ...    ...  ...    ...   ...   ...        ...      ...    ...
# 999995    1.5    1.5  ...   11.0   1.0   1.0          0      NaN    NaN
# 999996    1.2    1.5  ...   11.0   1.0   0.0          1      NaN    NaN
# 999997    0.2    1.0  ...   12.0   1.0   0.0          1      NaN    NaN
# 999998    0.8    0.9  ...   35.0   2.0   1.0          0      NaN    NaN
# 999999    1.2    1.2  ...   15.0   1.0   0.0          0      NaN    NaN
#
#         치아마모증유무  제3대구치(사랑니)이상   치석   데이터공개일자
# 0           NaN           NaN  1.0  20181126
# 1           NaN           NaN  1.0  20181126
# 2           NaN           NaN  0.0  20181126
# 3           NaN           NaN  NaN  20181126
# 4           NaN           NaN  NaN  20181126
# ...         ...           ...  ...       ...
# 999995      NaN           NaN  NaN  20181126
# 999996      NaN           NaN  0.0  20181126
# 999997      NaN           NaN  0.0  20181126
# 999998      NaN           NaN  NaN  20181126
# 999999      NaN           NaN  NaN  20181126
#
# [1000000 rows x 34 columns]

# %%
# 원본데이터의 튜플 수와 컬럼수 출력
rawData_org.shape
# Out:
# (1000000, 34)

# %%
# 의사결정트리에 사용할 속성리스트
feature_columns_to_use = ['성별코드', '연령대코드(5세단위)', '신장(5Cm단위)', '체중(5Kg 단위)', '허리둘레', '시력(좌)', '시력(우)',
                    '청력(좌)', '청력(우)', '수축기혈압', '이완기혈압', '식전혈당(공복혈당)', '트리글리세라이드', 'HDL콜레스테롤',
                    'LDL콜레스테롤', '요단백', '혈청크레아티닌', '(혈청지오티)AST', '(혈청지오티)ALT', '감마지티피', '흡연상태', '음주여부']

rawData = rawData_org[feature_columns_to_use]

# %%
# 속성값이 NULL인 튜플 제외
rawData = rawData.dropna()

# 인덱스 재설정
rawData.reset_index(inplace=True, drop=True)

# 원본데이터의 튜플 수와 컬럼수 출력
rawData.shape
# Out:
# (990910, 22)

# %%
import random as rd  # 샘플링을 위한 random 패키지 임포트

# 1) 샘플링을 통한 수량 축소
# 원본데이터 중 50,000개를 튜플만 샘플링
# len() : 데이터프레임의 크기를 구하는 함수
sample_idx = rd.sample(range(0, len(rawData)), 50000)

# 인덱스 값 정렬(오름차순)
sample_idx.sort()

sample_idx
# Out:
# [53,
#  73,
#  116,
#  122,
#  159,
#  163,
#  165,
#  171,
#  173,
#  251,
#  255,
#  283,
#  344,
#  362,
#  418,
#  424,
#  465,
#  480,
#  483,
#  487,
#  494,
#  498,
#  502,
#  549,
#  561,
#  573,
#  592,
#  594,
#  619,
#  622,
#  624,
#  626,
#  692,
#  696,
#  713,
#  725,
#  758,
#  773,
#  820,
#  821,
#  835,
#  864,
#  876,
#  886,
#  927,
#  938,
#  957,
#  966,
#  975,
#  1016,
#  1017,
#  1023,
#  1053,
#  1073,
#  1099,
#  1100,
#  1138,
#  1142,
#  1151,
#  1191,
#  1195,
#  1197,
#  1204,
#  1209,
#  1227,
#  1230,
#  1244,
#  1313,
#  1333,
#  1339,
#  1341,
#  1370,
#  1388,
#  1400,
#  1501,
#  1507,
#  1544,
#  1545,
#  1546,
#  1577,
#  1584,
#  1662,
#  1668,
#  1681,
#  1697,
#  1703,
#  1775,
#  1778,
#  1779,
#  1793,
#  1836,
#  1863,
#  1872,
#  1881,
#  1891,
#  1949,
#  1951,
#  1961,
#  1968,
#  1980,
#  1986,
#  1992,
#  1998,
#  2040,
#  2044,
#  2057,
#  2086,
#  2090,
#  2126,
#  2151,
#  2171,
#  2201,
#  2230,
#  2237,
#  2279,
#  2301,
#  2354,
#  2371,
#  2373,
#  2392,
#  2436,
#  2453,
#  2496,
#  2510,
#  2520,
#  2522,
#  2536,
#  2560,
#  2593,
#  2621,
#  2647,
#  2687,
#  2723,
#  2729,
#  2735,
#  2766,
#  2797,
#  2807,
#  2815,
#  2823,
#  2837,
#  2853,
#  2867,
#  2888,
#  2938,
#  2976,
#  2990,
#  3007,
#  3015,
#  3026,
#  3045,
#  3051,
#  3076,
#  3078,
#  3129,
#  3213,
#  3214,
#  3236,
#  3271,
#  3295,
#  3304,
#  3322,
#  3326,
#  3414,
#  3425,
#  3468,
#  3477,
#  3484,
#  3548,
#  3585,
#  3595,
#  3605,
#  3663,
#  3677,
#  3678,
#  3785,
#  3791,
#  3843,
#  3855,
#  3881,
#  3886,
#  3898,
#  3928,
#  3950,
#  3951,
#  3962,
#  3967,
#  3969,
#  3978,
#  3979,
#  3985,
#  4007,
#  4023,
#  4099,
#  4108,
#  4110,
#  4138,
#  4166,
#  4181,
#  4227,
#  4248,
#  4251,
#  4268,
#  4270,
#  4288,
#  4318,
#  4334,
#  4371,
#  4383,
#  4388,
#  4442,
#  4468,
#  4475,
#  4531,
#  4545,
#  4563,
#  4575,
#  4590,
#  4622,
#  4631,
#  4638,
#  4652,
#  4659,
#  4668,
#  4684,
#  4688,
#  4703,
#  4745,
#  4746,
#  4763,
#  4776,
#  4815,
#  4883,
#  4884,
#  4889,
#  4890,
#  4900,
#  4926,
#  4933,
#  4943,
#  4969,
#  5000,
#  5001,
#  5030,
#  5051,
#  5077,
#  5092,
#  5097,
#  5131,
#  5147,
#  5187,
#  5224,
#  5250,
#  5299,
#  5327,
#  5347,
#  5351,
#  5353,
#  5378,
#  5447,
#  5469,
#  5474,
#  5508,
#  5519,
#  5548,
#  5555,
#  5561,
#  5580,
#  5588,
#  5590,
#  5622,
#  5649,
#  5653,
#  5656,
#  5662,
#  5685,
#  5696,
#  5730,
#  5749,
#  5755,
#  5763,
#  5779,
#  5809,
#  5822,
#  5828,
#  5843,
#  5844,
#  5850,
#  5855,
#  5866,
#  5877,
#  5904,
#  5907,
#  5923,
#  5958,
#  5985,
#  6018,
#  6025,
#  6057,
#  6096,
#  6102,
#  6127,
#  6136,
#  6178,
#  6203,
#  6205,
#  6220,
#  6226,
#  6232,
#  6250,
#  6265,
#  6282,
#  6294,
#  6322,
#  6333,
#  6383,
#  6399,
#  6402,
#  6426,
#  6432,
#  6489,
#  6496,
#  6508,
#  6513,
#  6595,
#  6645,
#  6664,
#  6716,
#  6720,
#  6739,
#  6743,
#  6749,
#  6751,
#  6793,
#  6797,
#  6804,
#  6835,
#  6892,
#  6916,
#  6940,
#  6943,
#  6951,
#  6953,
#  6959,
#  6960,
#  6963,
#  6968,
#  6969,
#  6979,
#  6983,
#  6995,
#  7001,
#  7022,
#  7114,
#  7132,
#  7162,
#  7165,
#  7184,
#  7202,
#  7222,
#  7237,
#  7251,
#  7265,
#  7297,
#  7325,
#  7360,
#  7361,
#  7368,
#  7374,
#  7377,
#  7393,
#  7398,
#  7431,
#  7457,
#  7468,
#  7521,
#  7553,
#  7558,
#  7565,
#  7586,
#  7601,
#  7621,
#  7640,
#  7673,
#  7693,
#  7699,
#  7728,
#  7757,
#  7799,
#  7819,
#  7838,
#  7871,
#  7897,
#  7903,
#  7938,
#  7964,
#  7965,
#  7968,
#  7972,
#  7995,
#  8015,
#  8087,
#  8108,
#  8143,
#  8158,
#  8202,
#  8238,
#  8307,
#  8324,
#  8385,
#  8411,
#  8433,
#  8451,
#  8514,
#  8518,
#  8579,
#  8581,
#  8582,
#  8600,
#  8617,
#  8621,
#  8627,
#  8635,
#  8636,
#  8663,
#  8665,
#  8671,
#  8691,
#  8710,
#  8716,
#  8743,
#  8758,
#  8775,
#  8782,
#  8790,
#  8797,
#  8805,
#  8830,
#  8841,
#  8867,
#  8878,
#  8881,
#  8896,
#  8902,
#  8948,
#  8952,
#  8959,
#  9058,
#  9123,
#  9128,
#  9132,
#  9201,
#  9204,
#  9237,
#  9244,
#  9251,
#  9290,
#  9295,
#  9303,
#  9324,
#  9348,
#  9376,
#  9387,
#  9415,
#  9450,
#  9455,
#  9465,
#  9470,
#  9490,
#  9521,
#  9523,
#  9573,
#  9583,
#  9588,
#  9615,
#  9620,
#  9632,
#  9652,
#  9656,
#  9679,
#  9702,
#  9719,
#  9741,
#  9776,
#  9819,
#  9822,
#  9826,
#  9854,
#  9864,
#  9883,
#  9898,
#  9928,
#  9931,
#  9944,
#  9961,
#  9993,
#  10012,
#  10019,
#  10038,
#  10045,
#  10064,
#  10067,
#  10106,
#  10121,
#  10140,
#  10202,
#  10242,
#  10246,
#  10262,
#  10271,
#  10325,
#  10338,
#  10342,
#  10351,
#  10376,
#  10378,
#  10380,
#  10390,
#  10403,
#  10423,
#  10448,
#  10453,
#  10482,
#  10493,
#  10496,
#  10506,
#  10534,
#  10578,
#  10585,
#  10590,
#  10606,
#  10616,
#  10620,
#  10629,
#  10651,
#  10670,
#  10678,
#  10688,
#  10696,
#  10745,
#  10749,
#  10765,
#  10785,
#  10786,
#  10806,
#  10826,
#  10833,
#  10836,
#  10838,
#  10857,
#  10864,
#  10880,
#  10901,
#  10919,
#  10938,
#  10951,
#  10975,
#  11001,
#  11006,
#  11009,
#  11025,
#  11062,
#  11094,
#  11184,
#  11196,
#  11215,
#  11223,
#  11228,
#  11255,
#  11269,
#  11286,
#  11308,
#  11329,
#  11344,
#  11349,
#  11357,
#  11375,
#  11405,
#  11444,
#  11481,
#  11506,
#  11517,
#  11578,
#  11606,
#  11688,
#  11724,
#  11738,
#  11755,
#  11757,
#  11784,
#  11814,
#  11818,
#  11834,
#  11858,
#  11866,
#  11870,
#  11905,
#  11911,
#  11925,
#  11942,
#  11967,
#  12018,
#  12040,
#  12042,
#  12068,
#  12174,
#  12228,
#  12234,
#  12271,
#  12272,
#  12276,
#  12300,
#  12301,
#  12347,
#  12349,
#  12376,
#  12387,
#  12411,
#  12428,
#  12458,
#  12478,
#  12483,
#  12486,
#  12521,
#  12565,
#  12597,
#  12604,
#  12654,
#  12731,
#  12736,
#  12738,
#  12742,
#  12750,
#  12805,
#  12806,
#  12852,
#  12854,
#  12871,
#  12879,
#  12904,
#  12905,
#  12913,
#  12941,
#  12942,
#  12982,
#  12988,
#  13020,
#  13036,
#  13059,
#  13069,
#  13127,
#  13138,
#  13146,
#  13151,
#  13173,
#  13175,
#  13178,
#  13181,
#  13243,
#  13252,
#  13262,
#  13276,
#  13282,
#  13284,
#  13310,
#  13324,
#  13358,
#  13364,
#  13376,
#  13406,
#  13412,
#  13425,
#  13438,
#  13450,
#  13459,
#  13492,
#  13503,
#  13532,
#  13538,
#  13551,
#  13558,
#  13568,
#  13582,
#  13593,
#  13620,
#  13623,
#  13636,
#  13657,
#  13675,
#  13680,
#  13726,
#  13778,
#  13780,
#  13796,
#  13819,
#  13827,
#  13848,
#  13849,
#  13871,
#  13882,
#  13884,
#  13896,
#  13912,
#  13923,
#  13942,
#  13966,
#  13975,
#  13984,
#  13987,
#  14016,
#  14033,
#  14089,
#  14104,
#  14106,
#  14108,
#  14160,
#  14162,
#  14199,
#  14204,
#  14234,
#  14252,
#  14266,
#  14335,
#  14370,
#  14376,
#  14409,
#  14412,
#  14417,
#  14436,
#  14469,
#  14476,
#  14489,
#  14542,
#  14576,
#  14587,
#  14617,
#  14661,
#  14674,
#  14676,
#  14765,
#  14773,
#  14782,
#  14783,
#  14814,
#  14839,
#  14842,
#  14870,
#  14883,
#  14907,
#  14908,
#  14948,
#  15028,
#  15046,
#  15055,
#  15073,
#  15098,
#  15099,
#  15132,
#  15146,
#  15153,
#  15155,
#  15169,
#  15187,
#  15204,
#  15262,
#  15265,
#  15273,
#  15281,
#  15306,
#  15335,
#  15338,
#  15350,
#  15356,
#  15359,
#  15362,
#  15369,
#  15380,
#  15404,
#  15415,
#  15420,
#  15421,
#  15456,
#  15463,
#  15480,
#  15482,
#  15484,
#  15521,
#  15535,
#  15567,
#  15579,
#  15598,
#  15629,
#  15643,
#  15654,
#  15664,
#  15718,
#  15752,
#  15771,
#  15783,
#  15830,
#  15864,
#  15877,
#  15986,
#  16063,
#  16088,
#  16095,
#  16111,
#  16114,
#  16115,
#  16131,
#  16165,
#  16197,
#  16200,
#  16214,
#  16243,
#  16249,
#  16271,
#  16297,
#  16310,
#  16347,
#  16371,
#  16408,
#  16455,
#  16467,
#  16468,
#  16478,
#  16482,
#  16484,
#  16514,
#  16534,
#  16535,
#  16576,
#  16587,
#  16588,
#  16637,
#  16638,
#  16648,
#  16649,
#  16661,
#  16675,
#  16682,
#  16687,
#  16693,
#  16696,
#  16702,
#  16707,
#  16708,
#  16734,
#  16737,
#  16746,
#  16752,
#  16780,
#  16790,
#  16792,
#  16809,
#  16841,
#  16949,
#  16954,
#  16955,
#  16988,
#  17003,
#  17062,
#  17069,
#  17113,
#  17115,
#  17119,
#  17152,
#  17212,
#  17224,
#  17252,
#  17289,
#  17311,
#  17332,
#  17371,
#  17377,
#  17388,
#  17472,
#  17487,
#  17493,
#  17497,
#  17499,
#  17509,
#  17578,
#  17587,
#  17654,
#  17664,
#  17687,
#  17707,
#  17722,
#  17796,
#  17819,
#  17862,
#  17893,
#  17904,
#  17934,
#  17944,
#  17954,
#  18032,
#  18121,
#  18144,
#  18151,
#  18158,
#  18161,
#  18167,
#  18210,
#  18223,
#  18237,
#  18240,
#  18248,
#  18305,
#  18306,
#  18346,
#  18354,
#  18358,
#  18361,
#  18367,
#  18382,
#  18389,
#  18439,
#  18497,
#  18515,
#  18560,
#  18573,
#  18597,
#  18609,
#  18635,
#  18666,
#  18711,
#  18715,
#  18743,
#  18759,
#  18761,
#  18769,
#  18799,
#  18817,
#  18835,
#  18843,
#  18881,
#  18900,
#  18910,
#  18913,
#  18915,
#  18932,
#  18937,
#  18964,
#  18982,
#  19033,
#  19037,
#  19041,
#  19078,
#  19093,
#  19148,
#  19159,
#  19163,
#  19170,
#  19179,
#  19206,
#  19210,
#  19223,
#  19236,
#  19260,
#  19304,
#  19322,
#  19323,
#  19328,
#  19332,
#  19361,
#  19385,
#  19389,
#  19391,
#  19393,
#  19416,
#  19422,
#  19434,
#  19439,
#  19453,
#  19466,
#  19468,
#  19484,
#  19497,
#  19521,
#  19534,
#  19547,
#  19552,
#  19575,
#  19635,
#  19645,
#  19658,
#  19680,
#  19697,
#  19702,
#  19721,
#  19725,
#  19740,
#  19755,
#  19762,
#  19763,
#  19773,
#  19775,
#  19781,
#  ...]

# %%
# 샘플링 된 인덱스로 구성된 샘플 데이터프레임 생성
rawData_sample = rawData.loc[sample_idx]

rawData_sample.reset_index(inplace=True, drop=True) #  인덱스 재설정


# 첫 10개의 행만 출력
rawData_sample.head(10)
# Out:
#    성별코드  연령대코드(5세단위)  신장(5Cm단위)  체중(5Kg 단위)  허리둘레  시력(좌)  시력(우)  청력(좌)  청력(우)  \
# 0     2           10      160.0        60.0  80.0    0.7    0.8    1.0    1.0
# 1     1           10      175.0        60.0  82.0    0.9    1.2    1.0    1.0
# 2     1            9      175.0        85.0  93.0    1.5    1.5    1.0    1.0
# 3     1           12      170.0        70.0  93.0    0.9    1.0    1.0    1.0
# 4     1           13      175.0        80.0  95.0    1.5    1.2    1.0    1.0
# 5     2           15      140.0        55.0  77.0    0.5    0.8    1.0    1.0
# 6     2           11      150.0        65.0  84.0    1.0    1.0    1.0    1.0
# 7     1            9      180.0        75.0  81.1    1.5    1.5    1.0    1.0
# 8     1            6      170.0        70.0  86.0    1.5    2.0    1.0    1.0
# 9     2           13      160.0        75.0  91.2    0.5    0.6    1.0    1.0
#
#    수축기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  요단백  혈청크레아티닌  (혈청지오티)AST  \
# 0  120.0  ...     105.0      62.0      86.0  1.0      0.9        17.0
# 1  120.0  ...     186.0      62.0      62.0  1.0      0.7        22.0
# 2  128.0  ...     268.0      54.0     141.0  1.0      1.2        24.0
# 3  106.0  ...      94.0      50.0     132.0  1.0      0.8        18.0
# 4  129.0  ...     117.0      62.0     123.0  1.0      1.1        25.0
# 5  130.0  ...      92.0      52.0     183.0  1.0      1.1        25.0
# 6  137.0  ...     110.0      50.0      94.0  1.0      0.6        27.0
# 7  134.0  ...     369.0      55.0     160.0  3.0      1.2        29.0
# 8  118.0  ...      69.0      57.0     119.0  1.0      0.9        38.0
# 9  150.0  ...      78.0      52.0      99.0  1.0      0.9        17.0
#
#    (혈청지오티)ALT  감마지티피  흡연상태  음주여부
# 0        11.0   13.0   1.0   0.0
# 1        12.0   98.0   1.0   1.0
# 2        28.0   28.0   2.0   1.0
# 3        13.0   25.0   1.0   1.0
# 4        30.0   21.0   2.0   0.0
# 5        15.0   15.0   1.0   0.0
# 6        32.0   20.0   1.0   0.0
# 7        46.0   89.0   3.0   1.0
# 8        57.0   24.0   2.0   1.0
# 9        14.0   17.0   1.0   0.0
#
# [10 rows x 22 columns]

# %%
rawData_sample.shape
# Out:
# (50000, 22)

# %%
feature_columns_to_use = ['성별코드', '연령대코드', '신장', '체중', '허리둘레', '시력_좌', '시력_우',
                    '청력_좌', '청력_우', '수축기혈압', '이완기혈압', '식전혈당', '트리글리세라이드', 'HDL콜레스테롤',
                    'LDL콜레스테롤', '요단백', '혈청크레아티닌', '혈청지오티_AST', '혈청지오티_ALT', '감마지티피', '흡연상태', '음주여부']

rawData_sample.rename(columns = {'연령대코드(5세단위)' : '연령대코드',
                                 '신장(5Cm단위)' : '신장',
                                 '체중(5Kg 단위)' : '체중',
                                 '시력(좌)' : '시력_좌',
                                 '시력(우)' : '시력_우',
                                 '청력(좌)' : '청력_좌',
                                 '청력(우)' : '청력_우',
                                 '식전혈당(공복혈당)' : '식전혈당',
                                 '(혈청지오티)AST' : '혈청지오티_AST',
                                 '(혈청지오티)ALT' : '혈청지오티_ALT'}, inplace = True)

from sklearn.preprocessing import StandardScaler  # sklearn.preprocessing의 StandardScaler 모듈 임포트

# StandardScaler() : Z-score 정규화 함수
stdscaler = StandardScaler()

rawData_sam_std = pd.DataFrame(stdscaler.fit_transform(rawData_sample.loc[:, '성별코드' : '음주여부']), columns = feature_columns_to_use)

# nonnumeric 속성을 categrical 데이터로 변환
nonnumeric_columns = ['성별코드','음주여부']

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
for feature in nonnumeric_columns:
    rawData_sam_std[feature] = le.fit_transform(rawData_sam_std[feature])
    
rawData_sam_std
# Out:
#        성별코드     연령대코드        신장        체중      허리둘레      시력_좌      시력_우  \
# 0         1 -0.195272 -0.232224 -0.266260 -0.120177 -0.457232 -0.289735
# 1         0 -0.195272  1.365796 -0.266260  0.055541 -0.130743  0.351548
# 2         0 -0.546619  1.365796  1.681678  1.021993  0.848725  0.832510
# 3         0  0.507423  0.833123  0.512915  1.021993 -0.130743  0.030907
# 4         0  0.858771  1.365796  1.292091  1.197711  0.848725  0.351548
# ...     ...       ...       ...       ...       ...       ...       ...
# 49995     0  0.156076  0.300449 -0.266260 -0.401327 -0.457232  0.030907
# 49996     0 -0.897967  1.898470  2.071266  0.758415  0.358991  0.832510
# 49997     1  1.561466 -1.830245 -1.435022 -0.559473 -0.293987 -0.931017
# 49998     0 -1.600662  0.833123  0.512915 -0.295896  0.848725  0.832510
# 49999     1  1.210118 -0.232224  0.512915  0.319119 -0.457232 -0.289735
#
#            청력_좌      청력_우     수축기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  \
# 0     -0.182814 -0.181172 -0.177177  ... -0.270653  0.340417 -0.773167
# 1     -0.182814 -0.181172 -0.177177  ...  0.522543  0.340417 -1.467225
# 2     -0.182814 -0.181172  0.369429  ...  1.325532 -0.190738  0.817381
# 3     -0.182814 -0.181172 -1.133737  ... -0.378371 -0.456315  0.557110
# 4     -0.182814 -0.181172  0.437755  ... -0.153142  0.340417  0.296838
# ...         ...       ...       ...  ...       ...       ...       ...
# 49995 -0.182814 -0.181172 -0.587131  ... -0.456711 -0.589104 -0.744248
# 49996 -0.182814 -0.181172 -0.177177  ... -0.593806  3.460951 -1.929930
# 49997 -0.182814 -0.181172  0.847709  ...  0.140634  0.340417 -1.640740
# 49998 -0.182814 -0.181172  0.506081  ... -0.691732 -0.721892 -0.628572
# 49999 -0.182814 -0.181172  0.506081  ... -0.339200 -0.522709 -0.946682
#
#             요단백   혈청크레아티닌  혈청지오티_AST  혈청지오티_ALT     감마지티피      흡연상태  음주여부
# 0     -0.214334  0.079971  -0.301296  -0.563329 -0.477640 -0.741192     0
# 1     -0.214334 -0.349264  -0.135175  -0.524952  1.223506 -0.741192     1
# 2     -0.214334  0.723822  -0.068727   0.089095 -0.177437  0.483595     1
# 3     -0.214334 -0.134646  -0.268072  -0.486574 -0.237478 -0.741192     1
# 4     -0.214334  0.509205  -0.035503   0.165851 -0.317532  0.483595     0
# ...         ...       ...        ...        ...       ...       ...   ...
# 49995 -0.214334  0.079971  -0.234848  -0.333062  0.002684  0.483595     1
# 49996 -0.214334  0.079971  -0.268072  -0.256306 -0.397586  1.708381     0
# 49997 -0.214334  0.079971   2.688882   5.116602  0.022697 -0.741192     0
# 49998 -0.214334 -0.349264  -0.268072  -0.371440 -0.537680  0.483595     1
# 49999 -0.214334  0.294588  -0.068727  -0.333062 -0.357559 -0.741192     0
#
# [50000 rows x 22 columns]

# %%
feature_columns_to_use[0:len(feature_columns_to_use)] #:8,10:21]
# Out:
# ['성별코드',
#  '연령대코드',
#  '신장',
#  '체중',
#  '허리둘레',
#  '시력_좌',
#  '시력_우',
#  '청력_좌',
#  '청력_우',
#  '수축기혈압',
#  '이완기혈압',
#  '식전혈당',
#  '트리글리세라이드',
#  'HDL콜레스테롤',
#  'LDL콜레스테롤',
#  '요단백',
#  '혈청크레아티닌',
#  '혈청지오티_AST',
#  '혈청지오티_ALT',
#  '감마지티피',
#  '흡연상태',
#  '음주여부']

# %%
# 소스 데이터프레임에서 예측(prediction)을 위한 속성 집합
# X = rawData.loc[:, feature_columns_to_use[0:8, 10:21]]  
y = rawData_sam_std.loc[:, feature_columns_to_use[9]]  # 종속변수(예측속성, 수축기혈압)
del feature_columns_to_use[9]
X = rawData_sam_std.loc[:, feature_columns_to_use]  # 독립변수

# %%
X
# Out:
#        성별코드     연령대코드        신장        체중      허리둘레      시력_좌      시력_우  \
# 0         1 -0.195272 -0.232224 -0.266260 -0.120177 -0.457232 -0.289735
# 1         0 -0.195272  1.365796 -0.266260  0.055541 -0.130743  0.351548
# 2         0 -0.546619  1.365796  1.681678  1.021993  0.848725  0.832510
# 3         0  0.507423  0.833123  0.512915  1.021993 -0.130743  0.030907
# 4         0  0.858771  1.365796  1.292091  1.197711  0.848725  0.351548
# ...     ...       ...       ...       ...       ...       ...       ...
# 49995     0  0.156076  0.300449 -0.266260 -0.401327 -0.457232  0.030907
# 49996     0 -0.897967  1.898470  2.071266  0.758415  0.358991  0.832510
# 49997     1  1.561466 -1.830245 -1.435022 -0.559473 -0.293987 -0.931017
# 49998     0 -1.600662  0.833123  0.512915 -0.295896  0.848725  0.832510
# 49999     1  1.210118 -0.232224  0.512915  0.319119 -0.457232 -0.289735
#
#            청력_좌      청력_우     이완기혈압  ...  트리글리세라이드  HDL콜레스테롤  LDL콜레스테롤  \
# 0     -0.182814 -0.181172 -0.619305  ... -0.270653  0.340417 -0.773167
# 1     -0.182814 -0.181172  0.391280  ...  0.522543  0.340417 -1.467225
# 2     -0.182814 -0.181172  0.593397  ...  1.325532 -0.190738  0.817381
# 3     -0.182814 -0.181172 -0.619305  ... -0.378371 -0.456315  0.557110
# 4     -0.182814 -0.181172  0.492339  ... -0.153142  0.340417  0.296838
# ...         ...       ...       ...  ...       ...       ...       ...
# 49995 -0.182814 -0.181172 -0.215071  ... -0.456711 -0.589104 -0.744248
# 49996 -0.182814 -0.181172  0.391280  ... -0.593806  3.460951 -1.929930
# 49997 -0.182814 -0.181172 -1.225655  ...  0.140634  0.340417 -1.640740
# 49998 -0.182814 -0.181172  1.300807  ... -0.691732 -0.721892 -0.628572
# 49999 -0.182814 -0.181172  0.088105  ... -0.339200 -0.522709 -0.946682
#
#             요단백   혈청크레아티닌  혈청지오티_AST  혈청지오티_ALT     감마지티피      흡연상태  음주여부
# 0     -0.214334  0.079971  -0.301296  -0.563329 -0.477640 -0.741192     0
# 1     -0.214334 -0.349264  -0.135175  -0.524952  1.223506 -0.741192     1
# 2     -0.214334  0.723822  -0.068727   0.089095 -0.177437  0.483595     1
# 3     -0.214334 -0.134646  -0.268072  -0.486574 -0.237478 -0.741192     1
# 4     -0.214334  0.509205  -0.035503   0.165851 -0.317532  0.483595     0
# ...         ...       ...        ...        ...       ...       ...   ...
# 49995 -0.214334  0.079971  -0.234848  -0.333062  0.002684  0.483595     1
# 49996 -0.214334  0.079971  -0.268072  -0.256306 -0.397586  1.708381     0
# 49997 -0.214334  0.079971   2.688882   5.116602  0.022697 -0.741192     0
# 49998 -0.214334 -0.349264  -0.268072  -0.371440 -0.537680  0.483595     1
# 49999 -0.214334  0.294588  -0.068727  -0.333062 -0.357559 -0.741192     0
#
# [50000 rows x 21 columns]

# %%
y
# Out:
# 0       -0.177177
# 1       -0.177177
# 2        0.369429
# 3       -1.133737
# 4        0.437755
#            ...
# 49995   -0.587131
# 49996   -0.177177
# 49997    0.847709
# 49998    0.506081
# 49999    0.506081
# Name: 수축기혈압, Length: 50000, dtype: float64

# %%
from patsy import dmatrices
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
features = ""

for attr in feature_columns_to_use[:-1] :
    features = features + attr + "+"

features = features + feature_columns_to_use[len(feature_columns_to_use)-1]    
features
# Out:
# '성별코드+연령대코드+신장+체중+허리둘레+시력_좌+시력_우+청력_좌+청력_우+이완기혈압+식전혈당+트리글리세라이드+HDL콜레스테롤+LDL콜레스테롤+요단백+혈청크레아티닌+혈청지오티_AST+혈청지오티_ALT+감마지티피+흡연상태+음주여부'

# %%
# Break into left and right hand side; y and x
y, X = dmatrices('수축기혈압~'+features, data=rawData_sam_std, return_type="dataframe")

# %%
# For each Xi, calculate VIF
vif = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

# Fit X to y
result = sm.OLS(y, X).fit()

# %%
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  수축기혈압   R-squared:                       0.596
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     3517.
# Date:                Wed, 07 Jul 2021   Prob (F-statistic):               0.00
# Time:                        19:45:31   Log-Likelihood:                -48262.
# No. Observations:               50000   AIC:                         9.657e+04
# Df Residuals:                   49978   BIC:                         9.676e+04
# Df Model:                          21
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.0363      0.007      5.405      0.000       0.023       0.050
# 성별코드          -0.0721      0.010     -7.219      0.000      -0.092      -0.053
# 연령대코드          0.1713      0.004     46.789      0.000       0.164       0.178
# 신장            -0.0627      0.005    -11.853      0.000      -0.073      -0.052
# 체중             0.1111      0.006     20.100      0.000       0.100       0.122
# 허리둘레           0.0187      0.004      4.328      0.000       0.010       0.027
# 시력_좌          -0.0049      0.003     -1.634      0.102      -0.011       0.001
# 시력_우          -0.0074      0.003     -2.462      0.014      -0.013      -0.002
# 청력_좌           0.0075      0.003      2.219      0.026       0.001       0.014
# 청력_우           0.0099      0.003      2.953      0.003       0.003       0.017
# 이완기혈압          0.6835      0.003    222.761      0.000       0.677       0.689
# 식전혈당           0.0365      0.003     12.039      0.000       0.031       0.042
# 트리글리세라이드       0.0104      0.003      3.181      0.001       0.004       0.017
# HDL콜레스테롤       0.0133      0.003      4.036      0.000       0.007       0.020
# LDL콜레스테롤      -0.0241      0.003     -8.380      0.000      -0.030      -0.018
# 요단백            0.0195      0.003      6.772      0.000       0.014       0.025
# 혈청크레아티닌        0.0008      0.003      0.260      0.795      -0.005       0.007
# 혈청지오티_AST      0.0076      0.004      1.717      0.086      -0.001       0.016
# 혈청지오티_ALT     -0.0187      0.005     -3.978      0.000      -0.028      -0.010
# 감마지티피          0.0128      0.003      3.893      0.000       0.006       0.019
# 흡연상태          -0.0245      0.004     -6.760      0.000      -0.032      -0.017
# 음주여부          -0.0053      0.007     -0.807      0.420      -0.018       0.008
# ==============================================================================
# Omnibus:                     3324.019   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             5857.541
# Skew:                           0.504   Prob(JB):                         0.00
# Kurtosis:                       4.340   Cond. No.                         7.93
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# For each X, calculate VIF and save in dataframe
vif = pd.DataFrame()
vif["VIF Factor"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif["features"] = X.columns

# %%
vif.round(1)
# Out:
#     VIF Factor   features
# 0          5.6  Intercept
# 1          3.1       성별코드
# 2          1.7      연령대코드
# 3          3.5         신장
# 4          3.8         체중
# 5          2.3       허리둘레
# 6          1.1       시력_좌
# 7          1.1       시력_우
# 8          1.4       청력_좌
# 9          1.4       청력_우
# 10         1.2      이완기혈압
# 11         1.1       식전혈당
# 12         1.3   트리글리세라이드
# 13         1.3   HDL콜레스테롤
# 14         1.0   LDL콜레스테롤
# 15         1.0        요단백
# 16         1.1    혈청크레아티닌
# 17         2.4  혈청지오티_AST
# 18         2.7  혈청지오티_ALT
# 19         1.3      감마지티피
# 20         1.6       흡연상태
# 21         1.3       음주여부

# %%
float(np.mean((result.predict(X) - rawData_sam_std['수축기혈압'])**2))
# Out:
# 0.4035743877040521

# %%
# RMSLE 계산하는 사용자정의 함수
from sklearn.metrics import make_scorer

def rmsle(predicted_values, actual_values) :
    # 넘파이로 배열 형태로 변환
    predicted_values = np.array(predicted_values)
    actual_values = np.array(actual_values)
    
    # 예측값과 실제값에 1을 더하고 로그를 씌움
    log_predict = np.log(predicted_values + 1)
    log_actual = np.log(actual_values + 1)
    
    # 위에서 계산한 예측값에서 실제값을 빼주고 제곱을 함
    difference = log_predict - log_actual
    # difference = (log_predict - log_actual) ** 2
    difference = np.square(difference)
    
    # 평균값 구함
    mean_difference = difference.mean()
    
    # 다시 루트를 씌움
    score = np.sqrt(mean_difference)
    
    return score

#rmsle_scorer = make_scorer(rmsle)
#rmsle_scorer

rmsle_score = rmsle(result.predict(X), rawData_sam_std['수축기혈압'])
rmsle_score
# Out:
# <ipython-input-23-e292a1cc18fa>:10: RuntimeWarning: invalid value encountered in log
#   log_predict = np.log(predicted_values + 1)
# <ipython-input-23-e292a1cc18fa>:11: RuntimeWarning: invalid value encountered in log
#   log_actual = np.log(actual_values + 1)
# nan

# %%
(result.predict(X) - rawData_sam_std['수축기혈압']).tail(100)
# Out:
# 49900   -0.409239
# 49901   -0.176442
# 49902    0.493279
# 49903    0.649919
# 49904   -0.004507
#            ...
# 49995    0.414240
# 49996    0.491828
# 49997   -1.544373
# 49998    0.079259
# 49999   -0.166117
# Length: 100, dtype: float64
